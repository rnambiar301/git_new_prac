# %% [markdown]
# <a href="https://colab.research.google.com/github/rnambiar301/git_new_prac/blob/main/Panda_multiple_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
# !python --version
# Out:
# Python 3.10.11

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 7.34.0
# ipykernel        : 5.5.6
# ipywidgets       : 7.7.1
# jupyter_client   : 6.1.12
# jupyter_core     : 5.3.0
# jupyter_server   : 1.24.0
# jupyterlab       : not installed
# nbclient         : 0.7.4
# nbconvert        : 6.5.4
# nbformat         : 5.8.0
# notebook         : 6.4.8
# qtconsole        : not installed
# traitlets        : 5.7.1

# %%
from platform import python_version
python_version()
# Out:
# '3.10.11'

# %%
eng_url = 'https://andybek.com/pandas-eng'
state_url = 'https://andybek.com/pandas-state'
party_url = 'https://andybek.com/pandas-party'
liberal_url = 'https://andybek.com/pandas-liberal'
ivies_url = 'https://andybek.com/pandas-ivies'

# %%
eng = pd.read_csv(eng_url)
state = pd.read_csv(state_url)
party = pd.read_csv(party_url)
liberal = pd.read_csv(liberal_url)
ivies = pd.read_csv(ivies_url)

# %%
eng.head(3)
# Out:
#                                    School Name  School Type  \
# 0  Massachusetts Institute of Technology (MIT)  Engineering
# 1     California Institute of Technology (CIT)  Engineering
# 2                          Harvey Mudd College  Engineering
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $72,200.00              $126,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00

# %%
state.head(3)
# Out:
#                           School Name School Type Starting Median Salary  \
# 0  University of California, Berkeley       State            $59,900.00
# 1        University of Virginia (UVA)       State            $52,700.00
# 2            Cal Poly San Luis Obispo       State            $57,200.00
#
#   Mid-Career Median Salary
# 0             $112,000.00
# 1             $103,000.00
# 2             $101,000.00

# %%
party.head(3)
# Out:
#                                          School Name School Type  \
# 0  University of Illinois at Urbana-Champaign (UIUC)       Party
# 1               University of Maryland, College Park       Party
# 2     University of California, Santa Barbara (UCSB)       Party
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $52,900.00               $96,100.00
# 1            $52,000.00               $95,000.00
# 2            $50,500.00               $95,000.00

# %%
liberal.head(3)
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00
# 2             $107,000.00

# %%
ivies.head(3)
# Out:
#             School Name School Type Starting Median Salary  \
# 0     Dartmouth College  Ivy League            $58,000.00
# 1  Princeton University  Ivy League            $66,500.00
# 2       Yale University  Ivy League            $59,100.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00

# %%
dfs = [eng,state,party,liberal,ivies]

# %%
for df in dfs:
  print(f'College shape : {df.shape}')
# Out:
# College shape : (19, 4)
# College shape : (175, 4)
# College shape : (20, 4)
# College shape : (47, 4)
# College shape : (8, 4)

# %%
pd.concat(dfs).loc[~pd.concat(dfs).duplicated(subset=['School Name'],keep='first')].sort_values(by='School Name')
# Out:
#                                School Name   School Type  \
# 2                          Amherst College  Liberal Arts
# 150           Appalachian State University         State
# 48          Arizona State University (ASU)         State
# 165        Arkansas State University (ASU)         State
# 39                       Auburn University         State
# ..                                     ...           ...
# 36                         Whitman College  Liberal Arts
# 11                        Williams College  Liberal Arts
# 39                   Wittenberg University  Liberal Arts
# 5    Worcester Polytechnic Institute (WPI)   Engineering
# 2                          Yale University    Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 2              $54,500.00              $107,000.00
# 150            $40,400.00               $69,100.00
# 48             $47,400.00               $84,100.00
# 165            $38,700.00               $63,300.00
# ...

# %%
schools = pd.concat(dfs).drop_duplicates(subset='School Name')

# %%
schools.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $72,200.00              $126,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $62,400.00              $114,000.00
# 4            $62,200.00              $114,000.00

# %%
schools.reset_index(drop=True,inplace=True)

# %%
schools.set_index('School Name')
# Out:
#                                               School Type  \
# School Name
# Massachusetts Institute of Technology (MIT)   Engineering
# California Institute of Technology (CIT)      Engineering
# Harvey Mudd College                           Engineering
# Polytechnic University of New York, Brooklyn  Engineering
# Cooper Union                                  Engineering
# ...                                                   ...
# Harvard University                             Ivy League
# University of Pennsylvania                     Ivy League
# Cornell University                             Ivy League
# Brown University                               Ivy League
# Columbia University                            Ivy League
#
#                                              Starting Median Salary  \
# School Name
# Massachusetts Institute of Technology (MIT)             $72,200.00
# California Institute of Technology (CIT)                $75,500.00
# ...

# %%
df1 = pd.concat([liberal,state])

# %%
df1.shape
# Out:
# (222, 4)

# %%
df1.drop_duplicates(subset='School Name')
# Out:
#                              School Name   School Type Starting Median Salary  \
# 0                    Bucknell University  Liberal Arts            $54,100.00
# 1                     Colgate University  Liberal Arts            $52,800.00
# 2                        Amherst College  Liberal Arts            $54,500.00
# 3                      Lafayette College  Liberal Arts            $53,900.00
# 4                        Bowdoin College  Liberal Arts            $48,100.00
# ..                                   ...           ...                    ...
# 170         Austin Peay State University         State            $37,700.00
# 171           Pittsburg State University         State            $40,400.00
# 172             Southern Utah University         State            $41,900.00
# 173  Montana State University - Billings         State            $37,900.00
# 174         Black Hills State University         State            $35,300.00
#
#     Mid-Career Median Salary
# ...

# %%
df1.loc[:,'Starting Median Salary'].replace(r'\$|,','',regex=True).astype(float).agg('mean')
# Out:
# 44469.36936936937

# %%
df1 = pd.concat([liberal.loc[:,['School Name','Mid-Career Median Salary']].sort_values('Mid-Career Median Salary',ascending=False).head(3).reset_index(drop=True),
                 state.loc[:,['School Name','Mid-Career Median Salary']].sort_values('Mid-Career Median Salary',ascending=False).head(3).reset_index(drop=True).loc[:,['School Name','Mid-Career Median Salary']]],axis=1)

# %%
df1
# Out:
#                                      School Name Mid-Career Median Salary  \
# 0  Wesleyan University (Middletown, Connecticut)              $97,900.00
# 1                                  Bates College              $96,500.00
# 2                                  Union College              $95,800.00
#
#                               School Name Mid-Career Median Salary
# 0         University of California, Davis              $99,600.00
# 1  University of Colorado - Boulder (UCB)              $97,600.00
# 2  University of California, Irvine (UCI)              $96,700.00

# %%
state.loc[:,['School Name','Mid-Career Median Salary']].sort_values('Mid-Career Median Salary').head(3).reset_index(drop=True).loc[:,['School Name','Mid-Career Median Salary']]
# Out:
#                                       School Name Mid-Career Median Salary
# 0                        Cal Poly San Luis Obispo             $101,000.00
# 1  University of California at Los Angeles (UCLA)             $101,000.00
# 2      University of California, San Diego (UCSD)             $101,000.00

# %%
df2 = pd.concat([liberal.loc[:,['School Name','Mid-Career Median Salary']].sort_values('Mid-Career Median Salary',ascending=False).head(3).reset_index(drop=True),\
                 state.loc[:,['School Name','Mid-Career Median Salary']].sort_values('Mid-Career Median Salary',ascending=False).head(3).reset_index(drop=True).\
                 loc[:,['School Name','Mid-Career Median Salary']]],axis=1,keys=['lLineral Arts','State'])

# %%
df2
# Out:
#                                    lLineral Arts                           \
#                                      School Name Mid-Career Median Salary
# 0  Wesleyan University (Middletown, Connecticut)              $97,900.00
# 1                                  Bates College              $96,500.00
# 2                                  Union College              $95,800.00
#
#                                     State
#                               School Name Mid-Career Median Salary
# 0         University of California, Davis              $99,600.00
# 1  University of Colorado - Boulder (UCB)              $97,600.00
# 2  University of California, Irvine (UCI)              $96,700.00
