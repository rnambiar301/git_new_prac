# %% [markdown]
# <a href="https://colab.research.google.com/github/rnambiar301/git_new_prac/blob/main/PandasAdvanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
data_url = 'https://andybek.com/pandas-soccer'

# %%
players = pd.read_csv(data_url)

# %%
players.shape
# Out:
# (465, 17)

# %%
players.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 17 entries, name to new_signing
# dtypes: float64(2), int64(10), object(5)
# memory usage: 61.9+ KB

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          465 non-null    object
#  1   club          465 non-null    object
#  2   age           465 non-null    int64
#  3   position      464 non-null    object
#  4   position_cat  465 non-null    int64
#  5   market_value  462 non-null    float64
#  6   page_views    465 non-null    int64
#  7   fpl_value     465 non-null    float64
#  8   fpl_sel       465 non-null    object
#  9   fpl_points    465 non-null    int64
#  10  region        465 non-null    int64
#  11  nationality   465 non-null    object
#  12  new_foreign   465 non-null    int64
#  13  age_cat       465 non-null    int64
#  14  club_id       465 non-null    int64
#  15  big_club      465 non-null    int64
#  16  new_signing   465 non-null    int64
# dtypes: float64(2), int64(10), object(5)
# ...

# %%
players.club.unique()
# Out:
# array(['Arsenal', 'Bournemouth', 'Brighton+and+Hove', 'Burnley',
#        'Chelsea', 'Crystal+Palace', 'Everton', 'Huddersfield',
#        'Leicester+City', 'Liverpool', 'Manchester+City',
#        'Manchester+United', 'Newcastle+United', 'Southampton',
#        'Stoke+City', 'Swansea', 'Tottenham', 'Watford', 'West+Brom',
#        'West+Ham'], dtype=object)

# %%
players.club.unique().size
# Out:
# 20

# %%
players.position.isin(['RB','CF','LB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461     True
# 462     True
# 463     True
# 464     True
# Name: position, Length: 465, dtype: bool

# %%
players[players.position.isin(['RB','CF','LB'])]
# Out:
#                 name      club  age position  position_cat  market_value  \
# 5    Hector Bellerin   Arsenal   22       RB             3          30.0
# 6     Olivier Giroud   Arsenal   30       CF             1          22.0
# 7      Nacho Monreal   Arsenal   31       LB             3          13.0
# 18      Kieran Gibbs   Arsenal   27       LB             3          10.0
# 20     Danny Welbeck   Arsenal   26       CF             1          15.0
# ..               ...       ...  ...      ...           ...           ...
# 459   Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461   Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462        Sam Byram  West+Ham   23       RB             3           4.5
# 463  Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464     Diafra Sakho  West+Ham   27       CF             1          10.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# ...

# %%
eng_player = players.nationality == 'England'

# %%
total_market_value = 0 
for k in players.market_value.dropna() :
  total_market_value += k
total_market_value_avg = total_market_value / players.market_value.dropna().size
total_market_value_avg
# Out:
# 11.125649350649349

# %%
player_page_view = players.page_views.gt(4000)

# %%
new_player = players.new_signing.eq(1)

# %%
players.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %%
players.sort_values(by='age')
# Out:
#                        name               club  age position  position_cat  \
# 237            Ben Woodburn          Liverpool   17       LW             1
# 354              Josh Tymon         Stoke+City   18       LB             3
# 439           Jonathan Leko          West+Brom   18       RW             1
# 235  Trent Alexander-Arnold          Liverpool   18       RB             3
# 274         Marcus Rashford  Manchester+United   19       CF             1
# ..                      ...                ...  ...      ...           ...
# 340            Peter Crouch         Stoke+City   36       CF             1
# 150            Gareth Barry            Everton   36       DM             2
# 35              Artur Boruc        Bournemouth   37       GK             4
# 424          Gareth McAuley          West+Brom   37       CB             3
# 136          Julian Speroni     Crystal+Palace   38       GK             4
#
# ...

# %%
players.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.sort_index().head(5)
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.sort_index().sort_values('market_value',ascending=False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
players.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
players.sort_index(ascending=True).sort_values('market_value',ascending=False).head(3)
# Out:
#                name               club  age position  position_cat  \
# 96      Eden Hazard            Chelsea   26       LW             1
# 267      Paul Pogba  Manchester+United   24       CM             2
# 0    Alexis Sanchez            Arsenal   28       LW             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 96           75.0        4220       10.5   2.30%         224       2
# 267          75.0        7435        8.0  19.50%         115       2
# 0            65.0        4329       12.0  17.10%         264       3
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 96      Belgium            0        3        5         1            0
# 267      France            0        2       12         1            1
# 0         Chile            0        4        1         1            0

# %%
players.sort_values(by=['club','market_value'],ascending=[True,False])
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 31   Alexandre Lacazette   Arsenal   26       CF             1          40.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 451      Darren Randolph  West+Ham   30       GK             4           2.5
# 452        James Collins  West+Ham   33       CB             3           2.0
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players.index
# Out:
# RangeIndex(start=0, stop=465, step=1)

# %%
df2 = players.drop(index=[2,10,21]).drop(columns='market_value')

# %%
df2.isna()
# Out:
#       name   club    age  position  position_cat  page_views  fpl_value  \
# 0    False  False  False     False         False       False      False
# 1    False  False  False     False         False       False      False
# 3    False  False  False     False         False       False      False
# 4    False  False  False     False         False       False      False
# 5    False  False  False     False         False       False      False
# ..     ...    ...    ...       ...           ...         ...        ...
# 460  False  False  False     False         False       False      False
# 461  False  False  False     False         False       False      False
# 462  False  False  False     False         False       False      False
# 463  False  False  False     False         False       False      False
# 464  False  False  False     False         False       False      False
#
#      fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  club_id  \
# ...

# %%
df2.nationality.unique()
# Out:
# array(['Chile', 'Germany', 'England', 'France', 'Spain', 'Nigeria',
#        'Switzerland', 'Wales', 'Brazil', 'Egypt', 'Argentina', 'Colombia',
#        'Bosnia', 'Norway', 'Poland', 'Scotland', 'Congo DR', 'Ireland',
#        'Netherlands', 'Australia', "Cote d'Ivoire", 'Finland', 'Cameroon',
#        'Austria', 'Israel', 'Czech Republic', 'Northern Ireland',
#        'Canada', 'Belgium', 'Iceland', 'Serbia', 'Portugal', 'Ghana',
#        'South Korea', 'Mali', 'Senegal', 'Curacao', 'Denmark', 'Slovenia',
#        'Trinidad and Tobago', 'Bermuda', 'Benin', 'Algeria', 'Jamaica',
#        'Japan', 'Tunisia', 'Croatia', 'Estonia', 'Ecuador', 'Armenia',
#        'Italy', 'Sweden', 'United States', 'Morocco', 'The Gambia',
#        'Kenya', 'Greece', 'Uruguay', 'Romania', 'Venezuela',
#        'New Zealand'], dtype=object)

# %%
fromLong(12345)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-78828497e9bd> in <cell line: 1>()
# ----> 1 fromLong(12345)
#
# NameError: name 'fromLong' is not defined
